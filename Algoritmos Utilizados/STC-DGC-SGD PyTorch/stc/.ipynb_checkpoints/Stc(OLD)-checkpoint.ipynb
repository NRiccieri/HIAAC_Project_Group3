# %%
from google.colab import drive
drive.mount('/content/gdrive')
import sys
sys.path.append('/content/gdrive/My Drive')
import json
import time
import os
import argparse
import gc
import random
from tensorflow.keras import losses, metrics, optimizers

import numpy as np
import torch, torchvision
import torch.optim as optim

import data_utils
import neural_nets
import distributed_training_utils as dst
from distributed_training_utils import Client, Server
import experiment_manager as xpm
import default_hyperparameters as dhp

import copy
import easydict
import warnings
warnings.filterwarnings('ignore')
#parser = argparse.ArgumentParser()
#parser.add_argument("--schedule", default="main", type=str)
#parser.add_argument("--start", default=0, type=int)
#parser.add_argument("--end", default=None, type=int)
#parser.add_argument("--reverse_order", default=False, type=bool)
args = easydict.EasyDict({
    "schedule": 'main',
    "start": 0,
    "end": None,
    'reverse_order': False,
})
print("Torch Version: ", torch.__version__)
device = 'cpu'

#args = parser.parse_args()

# Load the Hyperparameters of all Experiments to be performed and set up the Experiments
with open('/content/gdrive/My Drive/federated_learning.json') as data_file:    
  experiments_raw = json.load(data_file)[args.schedule]

hp_dicts = [hp for x in experiments_raw for hp in xpm.get_all_hp_combinations(x)][args.start:args.end]
if args.reverse_order:
  hp_dicts = hp_dicts[::-1]
experiments = [xpm.Experiment(hyperparameters=hp) for hp in hp_dicts]

def weight(experiments, client, hp,f,tempo):
  start_time = time.time()
  client.compress_weight_update_up(compression=hp['compression_up'], accumulate=hp['accumulation_up'], count_bits=hp["count_bits"])
  end_time = time.time()
  #print("--- %s seconds ---" % (end_time - start_time))
  f.write(str(tempo)+" --- %s seconds ---\n" % (end_time - start_time))    

def run_experiments(experiments):
  print("Running {} Experiments..\n".format(len(experiments)))
  for xp_count, xp in enumerate(experiments):
    f= open("compress.txt","w+")
    tempo = 0
    torch.cuda.empty_cache()
    import gc
    gc.collect()
    hp = dhp.get_hp(xp.hyperparameters)
    hp['count_bits'] = True
    xp.prepare(hp)
    #print(xp)

    # Load the Data and split it among the Clients
    #print(hp)
    client_loaders, train_loader, test_loader, stats = data_utils.get_data_loaders(hp)
    # Instantiate Clients and Server with Neural Net
    net = getattr(neural_nets, hp['net'])
    clients = [Client(loader, net().to(device), hp, xp, id_num=i) for i, loader in enumerate(client_loaders)]
    server = Server(test_loader, net().to(device), hp, xp, stats)

    # Print optimizer specs
    print_model(device=clients[0])
    print_optimizer(device=clients[0])

    # Start Distributed Training Process
    print("Start Distributed Training..\n")
    t1 = time.time()

    for c_round in range(1, hp['communication_rounds']+1):
      tempo += 1

      participating_clients = random.sample(clients, int(len(clients)*hp['participation_rate'])) 

      # Clients do
      for client in participating_clients:
        client.synchronize_with_server(server)
        client.compute_weight_update(hp['local_iterations'])
        #print abaixo
        z = 1
        weight(experiments, client, hp,f,tempo)

      # Server does  
      server.aggregate_weight_updates(participating_clients, aggregation=hp['aggregation']) 
      server.compress_weight_update_down(compression=hp['compression_down'], accumulate=hp['accumulation_down'], count_bits=hp["count_bits"])

      # Evaluate  
      if xp.is_log_round(c_round):
        print("Experiment: {} ({}/{})".format(args.schedule, xp_count+1, len(experiments)))
        print("Evaluate...")
        results_train = server.evaluate(max_samples=5000, loader=train_loader)
        results_test = server.evaluate(max_samples=10000)
        
        # Logging
        xp.log({'communication_round' : c_round, 'lr' : clients[0].optimizer.__dict__['param_groups'][0]['lr'],
          'epoch' : clients[0].epoch, 'iteration' : c_round*hp['local_iterations']})
        xp.log({'client{}_loss'.format(client.id) : client.train_loss for client in clients}, printout=False)
        
        xp.log({key+'_train' : value for key, value in results_train.items()})
        xp.log({key+'_test' : value for key, value in results_test.items()})
        if hp["count_bits"]:
            xp.log({'bits_sent_up' : sum(participating_clients[0].bits_sent), 'bits_sent_down' : sum(server.bits_sent)})
        
        xp.log({'time' : time.time()-t1})

        # Save results to Disk
        if 'log_path' in hp and hp['log_path']:
          xp.save_to_disc(path=hp['log_path'])

        # Timing
        total_time = time.time()-t1
        avrg_time_per_c_round = (total_time)/c_round 
        e = int(avrg_time_per_c_round*(hp['communication_rounds']-c_round))
        print("Remaining Time (approx.):", '{:02d}:{:02d}:{:02d}'.format(e // 3600, (e % 3600 // 60), e % 60), 
                  "[{:.2f}%]\n".format(c_round/hp['communication_rounds']*100))

    # Delete objects to free up GPU memory
    del server; clients.clear()
    torch.cuda.empty_cache()
    f.close()

def print_optimizer(device):
  try:
    print("Optimizer:", device.hp['optimizer'])
    for key, value in device.optimizer.__dict__['defaults'].items():
      print(" -", key,":", value)

    hp = device.hp
    print(hp)
    base_batchsize = hp['batch_size']
    if hp['fix_batchsize']:
      client_batchsize = base_batchsize//hp['n_clients']
    else:
      client_batchsize = base_batchsize
    print('hi')
    total_batchsize = client_batchsize*hp['n_clients']
    print(" - batchsize (/ total): {} (/ {})".format(client_batchsize, total_batchsize))
    print()
  except:
    pass


def print_model(device):
  print("Model {}:".format(device.hp['net']))
  n = 0
  for key, value in device.model.named_parameters():
    print(' -', '{:30}'.format(key), list(value.shape))
    n += value.numel()
  print("Total number of Parameters: ", n) 
  print()


if __name__ == "__main__":
  run_experiments(experiments)
# Out:
# Mounted at /content/gdrive
# Torch Version:  1.10.0+cu111
# Running 1 Experiments..
#
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
#
# Data:
#  - Train Set: ((50000, 3, 32, 32),(50000,)), Range: [0.000, 255.000], Labels: 0,..,9
#  - Test Set: ((10000, 3, 32, 32),(10000,)), Range: [0.000, 255.000], Labels: 0,..,9
# Model vgg11:
#  - features.0.weight              [64, 3, 3, 3]
#  - features.0.bias                [64]
#  - features.3.weight              [128, 64, 3, 3]
#  - features.3.bias                [128]
#  - features.6.weight              [256, 128, 3, 3]
#  - features.6.bias                [256]
#  - features.8.weight              [256, 256, 3, 3]
#  - features.8.bias                [256]
#  - features.11.weight             [512, 256, 3, 3]
#  - features.11.bias               [512]
#  - features.13.weight             [512, 512, 3, 3]
#  - features.13.bias               [512]
#  - features.16.weight             [512, 512, 3, 3]
#  - features.16.bias               [512]
#  - features.18.weight             [512, 512, 3, 3]
#  - features.18.bias               [512]
#  - classifier.1.weight            [512, 512]
#  - classifier.1.bias              [512]
#  - classifier.4.weight            [512, 512]
#  - classifier.4.bias              [512]
#  - classifier.6.weight            [10, 512]
#  - classifier.6.bias              [10]
# Total number of Parameters:  9750922
#
# Optimizer: SGD
#  - lr : 0.05
#  - momentum : 0.9
#  - dampening : 0
#  - weight_decay : 0.0005
#  - nesterov : False
# {'local_iterations': 1, 'batch_size': 32, 'weight_decay': 0.0005, 'optimizer': 'SGD', 'momentum': 0.9, 'log_frequency': 1, 'aggregation': 'mean', 'count_bits': True, 'participation_rate': 1, 'balancedness': 0.9, 'type': 'CNN', 'lr': 0.05, 'lr_decay': ['LambdaLR', {'lr_lambda': <function <lambda> at 0x7f0eb011ad40>}], 'iterations': 100, 'compression_up': ['none', {}], 'compression_down': ['none', {}], 'accumulation_up': False, 'accumulation_down': False, 'dataset': 'cifar10', 'net': 'vgg11', 'n_clients': 15, 'classes_per_client': 10, 'log_path': 'results/VGG19/', 'finished': False, 'log_id': 11504, 'communication_rounds': 100}
# Start Distributed Training..
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 1, 'lr': 0.0495, 'epoch': 1, 'iteration': 1}
# {'loss_train': 2.3024766778945924, 'accuracy_train': 0.0924}
# {'loss_test': 2.3031448793411253, 'accuracy_test': 0.0911}
# {'bits_sent_up': 312029504, 'bits_sent_down': 312029504}
# {'time': 10.152896881103516}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:16:46 [1.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 2, 'lr': 0.0495, 'epoch': 1, 'iteration': 2}
# {'loss_train': 2.302239022254944, 'accuracy_train': 0.0924}
# {'loss_test': 2.3028927564620973, 'accuracy_test': 0.0939}
# {'bits_sent_up': 624059008, 'bits_sent_down': 624059008}
# {'time': 18.65974736213684}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:15:14 [2.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 3, 'lr': 0.0495, 'epoch': 1, 'iteration': 3}
# {'loss_train': 2.302009630203247, 'accuracy_train': 0.1042}
# {'loss_test': 2.302638623714447, 'accuracy_test': 0.0995}
# {'bits_sent_up': 936088512, 'bits_sent_down': 936088512}
# {'time': 26.835238456726074}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:14:28 [3.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 4, 'lr': 0.0495, 'epoch': 1, 'iteration': 4}
# {'loss_train': 2.301921911239624, 'accuracy_train': 0.104}
# {'loss_test': 2.3025286960601807, 'accuracy_test': 0.1}
# {'bits_sent_up': 1248118016, 'bits_sent_down': 1248118016}
# {'time': 34.905542612075806}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:13:58 [4.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 5, 'lr': 0.0495, 'epoch': 1, 'iteration': 5}
# {'loss_train': 2.3020762157440187, 'accuracy_train': 0.104}
# {'loss_test': 2.3026428198814393, 'accuracy_test': 0.1}
# {'bits_sent_up': 1560147520, 'bits_sent_down': 1560147520}
# {'time': 42.85602045059204}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:13:34 [5.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 6, 'lr': 0.0495, 'epoch': 1, 'iteration': 6}
# {'loss_train': 2.302537407875061, 'accuracy_train': 0.104}
# {'loss_test': 2.3030713033676147, 'accuracy_test': 0.1}
# {'bits_sent_up': 1872177024, 'bits_sent_down': 1872177024}
# {'time': 50.80633282661438}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:13:16 [6.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 7, 'lr': 0.0495, 'epoch': 1, 'iteration': 7}
# {'loss_train': 2.303512091636658, 'accuracy_train': 0.104}
# {'loss_test': 2.3039724040031433, 'accuracy_test': 0.1}
# {'bits_sent_up': 2184206528, 'bits_sent_down': 2184206528}
# {'time': 59.456294536590576}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:13:10 [7.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 8, 'lr': 0.0495, 'epoch': 1, 'iteration': 8}
# {'loss_train': 2.305319046974182, 'accuracy_train': 0.104}
# {'loss_test': 2.305683228969574, 'accuracy_test': 0.1}
# {'bits_sent_up': 2496236032, 'bits_sent_down': 2496236032}
# {'time': 67.87963533401489}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:13:00 [8.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 9, 'lr': 0.0495, 'epoch': 1, 'iteration': 9}
# {'loss_train': 2.3084667778015135, 'accuracy_train': 0.1058}
# {'loss_test': 2.308707072734833, 'accuracy_test': 0.1015}
# {'bits_sent_up': 2808265536, 'bits_sent_down': 2808265536}
# {'time': 76.18835520744324}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:12:50 [9.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 10, 'lr': 0.0495, 'epoch': 1, 'iteration': 10}
# {'loss_train': 2.3143168687820435, 'accuracy_train': 0.1444}
# {'loss_test': 2.3143717193603517, 'accuracy_test': 0.1383}
# {'bits_sent_up': 3120295040, 'bits_sent_down': 3120295040}
# {'time': 84.29497790336609}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:12:38 [10.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 11, 'lr': 0.0495, 'epoch': 1, 'iteration': 11}
# {'loss_train': 2.3255962419509886, 'accuracy_train': 0.1076}
# {'loss_test': 2.3254193758964536, 'accuracy_test': 0.1077}
# {'bits_sent_up': 3432324544, 'bits_sent_down': 3432324544}
# {'time': 92.47179532051086}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:12:28 [11.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 12, 'lr': 0.0495, 'epoch': 1, 'iteration': 12}
# {'loss_train': 2.347580523490906, 'accuracy_train': 0.0998}
# {'loss_test': 2.34710547208786, 'accuracy_test': 0.1005}
# {'bits_sent_up': 3744354048, 'bits_sent_down': 3744354048}
# {'time': 100.4505865573883}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:12:16 [12.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 13, 'lr': 0.0495, 'epoch': 1, 'iteration': 13}
# {'loss_train': 2.378838872909546, 'accuracy_train': 0.0996}
# {'loss_test': 2.3780587005615232, 'accuracy_test': 0.1}
# {'bits_sent_up': 4056383552, 'bits_sent_down': 4056383552}
# {'time': 109.02383804321289}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:12:09 [13.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 14, 'lr': 0.0495, 'epoch': 1, 'iteration': 14}
# {'loss_train': 2.4019315099716185, 'accuracy_train': 0.0996}
# {'loss_test': 2.4008647775650025, 'accuracy_test': 0.1}
# {'bits_sent_up': 4368413056, 'bits_sent_down': 4368413056}
# {'time': 117.63265991210938}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:12:02 [14.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 15, 'lr': 0.0495, 'epoch': 1, 'iteration': 15}
# {'loss_train': 2.385071496963501, 'accuracy_train': 0.0996}
# {'loss_test': 2.384188756942749, 'accuracy_test': 0.1}
# {'bits_sent_up': 4680442560, 'bits_sent_down': 4680442560}
# {'time': 126.14398622512817}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:11:54 [15.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 16, 'lr': 0.0495, 'epoch': 1, 'iteration': 16}
# {'loss_train': 2.3557759380340575, 'accuracy_train': 0.1014}
# {'loss_test': 2.355275194644928, 'accuracy_test': 0.102}
# {'bits_sent_up': 4992472064, 'bits_sent_down': 4992472064}
# {'time': 135.2285556793213}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:11:50 [16.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 17, 'lr': 0.049005, 'epoch': 2, 'iteration': 17}
# {'loss_train': 2.337685046195984, 'accuracy_train': 0.109}
# {'loss_test': 2.337525415420532, 'accuracy_test': 0.1035}
# {'bits_sent_up': 5304501568, 'bits_sent_down': 5304501568}
# {'time': 143.51596641540527}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:11:40 [17.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 18, 'lr': 0.049005, 'epoch': 2, 'iteration': 18}
# {'loss_train': 2.328475842475891, 'accuracy_train': 0.104}
# {'loss_test': 2.3285460114479064, 'accuracy_test': 0.1}
# {'bits_sent_up': 5616531072, 'bits_sent_down': 5616531072}
# {'time': 151.6285481452942}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:11:30 [18.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 19, 'lr': 0.049005, 'epoch': 2, 'iteration': 19}
# {'loss_train': 2.3227909851074218, 'accuracy_train': 0.104}
# {'loss_test': 2.323092930316925, 'accuracy_test': 0.1}
# {'bits_sent_up': 5928560576, 'bits_sent_down': 5928560576}
# {'time': 159.93989181518555}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:11:21 [19.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 20, 'lr': 0.049005, 'epoch': 2, 'iteration': 20}
# {'loss_train': 2.32015248298645, 'accuracy_train': 0.104}
# {'loss_test': 2.320611369609833, 'accuracy_test': 0.1}
# {'bits_sent_up': 6240590080, 'bits_sent_down': 6240590080}
# {'time': 168.99949860572815}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:11:16 [20.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 21, 'lr': 0.049005, 'epoch': 2, 'iteration': 21}
# {'loss_train': 2.319030661582947, 'accuracy_train': 0.104}
# {'loss_test': 2.3196779918670654, 'accuracy_test': 0.1}
# {'bits_sent_up': 6552619584, 'bits_sent_down': 6552619584}
# {'time': 177.28690099716187}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:11:06 [21.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 22, 'lr': 0.049005, 'epoch': 2, 'iteration': 22}
# {'loss_train': 2.318377203941345, 'accuracy_train': 0.104}
# {'loss_test': 2.319212694168091, 'accuracy_test': 0.1}
# {'bits_sent_up': 6864649088, 'bits_sent_down': 6864649088}
# {'time': 185.50237321853638}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:10:57 [22.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 23, 'lr': 0.049005, 'epoch': 2, 'iteration': 23}
# {'loss_train': 2.31844331741333, 'accuracy_train': 0.104}
# {'loss_test': 2.319518492221832, 'accuracy_test': 0.1}
# {'bits_sent_up': 7176678592, 'bits_sent_down': 7176678592}
# {'time': 193.43444347381592}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:10:47 [23.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 24, 'lr': 0.049005, 'epoch': 2, 'iteration': 24}
# {'loss_train': 2.318936252593994, 'accuracy_train': 0.104}
# {'loss_test': 2.3202864646911623, 'accuracy_test': 0.1}
# {'bits_sent_up': 7488708096, 'bits_sent_down': 7488708096}
# {'time': 201.40995359420776}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:10:37 [24.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 25, 'lr': 0.049005, 'epoch': 2, 'iteration': 25}
# {'loss_train': 2.3201232147216797, 'accuracy_train': 0.104}
# {'loss_test': 2.3218602085113527, 'accuracy_test': 0.1}
# {'bits_sent_up': 7800737600, 'bits_sent_down': 7800737600}
# {'time': 209.98751068115234}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:10:29 [25.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 26, 'lr': 0.049005, 'epoch': 2, 'iteration': 26}
# {'loss_train': 2.322390766143799, 'accuracy_train': 0.104}
# {'loss_test': 2.3246008443832396, 'accuracy_test': 0.1}
# {'bits_sent_up': 8112767104, 'bits_sent_down': 8112767104}
# {'time': 218.4967873096466}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:10:21 [26.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 27, 'lr': 0.049005, 'epoch': 2, 'iteration': 27}
# {'loss_train': 2.3273572874069215, 'accuracy_train': 0.104}
# {'loss_test': 2.3303700160980223, 'accuracy_test': 0.1}
# {'bits_sent_up': 8424796608, 'bits_sent_down': 8424796608}
# {'time': 226.83932852745056}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:10:13 [27.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 28, 'lr': 0.049005, 'epoch': 2, 'iteration': 28}
# {'loss_train': 2.336575860977173, 'accuracy_train': 0.104}
# {'loss_test': 2.3407989311218262, 'accuracy_test': 0.1}
# {'bits_sent_up': 8736826112, 'bits_sent_down': 8736826112}
# {'time': 234.9474594593048}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:10:04 [28.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 29, 'lr': 0.049005, 'epoch': 2, 'iteration': 29}
# {'loss_train': 2.3470813274383544, 'accuracy_train': 0.104}
# {'loss_test': 2.3526090025901794, 'accuracy_test': 0.1}
# {'bits_sent_up': 9048855616, 'bits_sent_down': 9048855616}
# {'time': 242.8729157447815}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:09:54 [29.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 30, 'lr': 0.049005, 'epoch': 2, 'iteration': 30}
# {'loss_train': 2.3524843883514404, 'accuracy_train': 0.104}
# {'loss_test': 2.359111478328705, 'accuracy_test': 0.1}
# {'bits_sent_up': 9360885120, 'bits_sent_down': 9360885120}
# {'time': 250.84823369979858}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:09:45 [30.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 31, 'lr': 0.049005, 'epoch': 2, 'iteration': 31}
# {'loss_train': 2.33657320022583, 'accuracy_train': 0.118}
# {'loss_test': 2.3427664017677308, 'accuracy_test': 0.1118}
# {'bits_sent_up': 9672914624, 'bits_sent_down': 9672914624}
# {'time': 259.3539135456085}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:09:37 [31.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 32, 'lr': 0.049005, 'epoch': 2, 'iteration': 32}
# {'loss_train': 2.3218302392959593, 'accuracy_train': 0.1468}
# {'loss_test': 2.3274624133110047, 'accuracy_test': 0.1436}
# {'bits_sent_up': 9984944128, 'bits_sent_down': 9984944128}
# {'time': 267.72151017189026}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:09:28 [32.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 33, 'lr': 0.04851495, 'epoch': 3, 'iteration': 33}
# {'loss_train': 2.3111252069473265, 'accuracy_train': 0.1338}
# {'loss_test': 2.3161991882324218, 'accuracy_test': 0.1276}
# {'bits_sent_up': 10296973632, 'bits_sent_down': 10296973632}
# {'time': 276.41084146499634}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:09:21 [33.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 34, 'lr': 0.04851495, 'epoch': 3, 'iteration': 34}
# {'loss_train': 2.3045514965057374, 'accuracy_train': 0.125}
# {'loss_test': 2.3094023871421814, 'accuracy_test': 0.1206}
# {'bits_sent_up': 10609003136, 'bits_sent_down': 10609003136}
# {'time': 284.29179286956787}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:09:11 [34.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 35, 'lr': 0.04851495, 'epoch': 3, 'iteration': 35}
# {'loss_train': 2.299317488670349, 'accuracy_train': 0.1314}
# {'loss_test': 2.3045391917228697, 'accuracy_test': 0.1262}
# {'bits_sent_up': 10921032640, 'bits_sent_down': 10921032640}
# {'time': 292.1578152179718}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:09:02 [35.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 36, 'lr': 0.04851495, 'epoch': 3, 'iteration': 36}
# {'loss_train': 2.2944543075561525, 'accuracy_train': 0.1406}
# {'loss_test': 2.3006322717666627, 'accuracy_test': 0.1364}
# {'bits_sent_up': 11233062144, 'bits_sent_down': 11233062144}
# {'time': 300.01559376716614}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:08:53 [36.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 37, 'lr': 0.04851495, 'epoch': 3, 'iteration': 37}
# {'loss_train': 2.2904121494293213, 'accuracy_train': 0.1362}
# {'loss_test': 2.298242976665497, 'accuracy_test': 0.1292}
# {'bits_sent_up': 11545091648, 'bits_sent_down': 11545091648}
# {'time': 308.3504741191864}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:08:45 [37.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 38, 'lr': 0.04851495, 'epoch': 3, 'iteration': 38}
# {'loss_train': 2.2879514360427855, 'accuracy_train': 0.1178}
# {'loss_test': 2.297843611240387, 'accuracy_test': 0.1132}
# {'bits_sent_up': 11857121152, 'bits_sent_down': 11857121152}
# {'time': 317.0080065727234}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:08:37 [38.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 39, 'lr': 0.04851495, 'epoch': 3, 'iteration': 39}
# {'loss_train': 2.2896508026123046, 'accuracy_train': 0.1102}
# {'loss_test': 2.302140467166901, 'accuracy_test': 0.1094}
# {'bits_sent_up': 12169150656, 'bits_sent_down': 12169150656}
# {'time': 325.4379053115845}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:08:29 [39.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 40, 'lr': 0.04851495, 'epoch': 3, 'iteration': 40}
# {'loss_train': 2.2762991428375243, 'accuracy_train': 0.1124}
# {'loss_test': 2.287822198867798, 'accuracy_test': 0.1108}
# {'bits_sent_up': 12481180160, 'bits_sent_down': 12481180160}
# {'time': 333.91514015197754}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:08:20 [40.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 41, 'lr': 0.04851495, 'epoch': 3, 'iteration': 41}
# {'loss_train': 2.2617570400238036, 'accuracy_train': 0.1248}
# {'loss_test': 2.2701658177375794, 'accuracy_test': 0.1187}
# {'bits_sent_up': 12793209664, 'bits_sent_down': 12793209664}
# {'time': 342.32600712776184}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:08:12 [41.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 42, 'lr': 0.04851495, 'epoch': 3, 'iteration': 42}
# {'loss_train': 2.256678538322449, 'accuracy_train': 0.1348}
# {'loss_test': 2.263040316104889, 'accuracy_test': 0.128}
# {'bits_sent_up': 13105239168, 'bits_sent_down': 13105239168}
# {'time': 350.4956133365631}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:08:04 [42.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 43, 'lr': 0.04851495, 'epoch': 3, 'iteration': 43}
# {'loss_train': 2.2514696502685547, 'accuracy_train': 0.1366}
# {'loss_test': 2.257003083229065, 'accuracy_test': 0.1306}
# {'bits_sent_up': 13417268672, 'bits_sent_down': 13417268672}
# {'time': 359.1604628562927}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:07:56 [43.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 44, 'lr': 0.04851495, 'epoch': 3, 'iteration': 44}
# {'loss_train': 2.2396759462356566, 'accuracy_train': 0.138}
# {'loss_test': 2.2460626983642578, 'accuracy_test': 0.1305}
# {'bits_sent_up': 13729298176, 'bits_sent_down': 13729298176}
# {'time': 367.74428701400757}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:07:48 [44.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 45, 'lr': 0.04851495, 'epoch': 3, 'iteration': 45}
# {'loss_train': 2.2357469511032106, 'accuracy_train': 0.1318}
# {'loss_test': 2.244964852333069, 'accuracy_test': 0.1271}
# {'bits_sent_up': 14041327680, 'bits_sent_down': 14041327680}
# {'time': 376.165057182312}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:07:39 [45.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 46, 'lr': 0.04851495, 'epoch': 3, 'iteration': 46}
# {'loss_train': 2.235325632095337, 'accuracy_train': 0.1356}
# {'loss_test': 2.2445018124580383, 'accuracy_test': 0.1304}
# {'bits_sent_up': 14353357184, 'bits_sent_down': 14353357184}
# {'time': 385.1032073497772}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:07:32 [46.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 47, 'lr': 0.04851495, 'epoch': 3, 'iteration': 47}
# {'loss_train': 2.223969783782959, 'accuracy_train': 0.1358}
# {'loss_test': 2.230668694972992, 'accuracy_test': 0.1325}
# {'bits_sent_up': 14665386688, 'bits_sent_down': 14665386688}
# {'time': 393.1668679714203}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:07:23 [47.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 48, 'lr': 0.04851495, 'epoch': 3, 'iteration': 48}
# {'loss_train': 2.21446674823761, 'accuracy_train': 0.1294}
# {'loss_test': 2.2177503943443297, 'accuracy_test': 0.1242}
# {'bits_sent_up': 14977416192, 'bits_sent_down': 14977416192}
# {'time': 401.1373567581177}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:07:14 [48.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 49, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 49}
# {'loss_train': 2.2087929153442385, 'accuracy_train': 0.1246}
# {'loss_test': 2.2103880071640014, 'accuracy_test': 0.1201}
# {'bits_sent_up': 15289445696, 'bits_sent_down': 15289445696}
# {'time': 409.60182785987854}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:07:06 [49.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 50, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 50}
# {'loss_train': 2.207905945777893, 'accuracy_train': 0.1356}
# {'loss_test': 2.210690734386444, 'accuracy_test': 0.1309}
# {'bits_sent_up': 15601475200, 'bits_sent_down': 15601475200}
# {'time': 418.24786138534546}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:58 [50.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 51, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 51}
# {'loss_train': 2.20113392829895, 'accuracy_train': 0.1382}
# {'loss_test': 2.204574131965637, 'accuracy_test': 0.1347}
# {'bits_sent_up': 15913504704, 'bits_sent_down': 15913504704}
# {'time': 426.653400182724}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:49 [51.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 52, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 52}
# {'loss_train': 2.1852215480804444, 'accuracy_train': 0.1364}
# {'loss_test': 2.1875043654441835, 'accuracy_test': 0.1328}
# {'bits_sent_up': 16225534208, 'bits_sent_down': 16225534208}
# {'time': 434.99204182624817}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:41 [52.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 53, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 53}
# {'loss_train': 2.1760053491592406, 'accuracy_train': 0.1702}
# {'loss_test': 2.1778738355636595, 'accuracy_test': 0.1607}
# {'bits_sent_up': 16537563712, 'bits_sent_down': 16537563712}
# {'time': 443.3524901866913}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:33 [53.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 54, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 54}
# {'loss_train': 2.169528059959412, 'accuracy_train': 0.1756}
# {'loss_test': 2.1704920959472656, 'accuracy_test': 0.1655}
# {'bits_sent_up': 16849593216, 'bits_sent_down': 16849593216}
# {'time': 451.64603996276855}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:24 [54.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 55, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 55}
# {'loss_train': 2.1662107849121095, 'accuracy_train': 0.1754}
# {'loss_test': 2.1671299719810486, 'accuracy_test': 0.1648}
# {'bits_sent_up': 17161622720, 'bits_sent_down': 17161622720}
# {'time': 460.39842319488525}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:16 [55.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 56, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 56}
# {'loss_train': 2.159166874885559, 'accuracy_train': 0.1798}
# {'loss_test': 2.1600507616996767, 'accuracy_test': 0.1733}
# {'bits_sent_up': 17473652224, 'bits_sent_down': 17473652224}
# {'time': 469.2176673412323}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:08 [56.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 57, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 57}
# {'loss_train': 2.1564687633514406, 'accuracy_train': 0.1812}
# {'loss_test': 2.1566409420967103, 'accuracy_test': 0.1764}
# {'bits_sent_up': 17785681728, 'bits_sent_down': 17785681728}
# {'time': 477.66921830177307}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:06:00 [57.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 58, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 58}
# {'loss_train': 2.1566590023040773, 'accuracy_train': 0.1816}
# {'loss_test': 2.158386912345886, 'accuracy_test': 0.178}
# {'bits_sent_up': 18097711232, 'bits_sent_down': 18097711232}
# {'time': 486.02317118644714}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:05:51 [58.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 59, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 59}
# {'loss_train': 2.184420509338379, 'accuracy_train': 0.1796}
# {'loss_test': 2.190787968635559, 'accuracy_test': 0.1688}
# {'bits_sent_up': 18409740736, 'bits_sent_down': 18409740736}
# {'time': 494.1967496871948}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:05:43 [59.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 60, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 60}
# {'loss_train': 2.142523455619812, 'accuracy_train': 0.1902}
# {'loss_test': 2.1456003689765932, 'accuracy_test': 0.1853}
# {'bits_sent_up': 18721770240, 'bits_sent_down': 18721770240}
# {'time': 502.61767864227295}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:05:35 [60.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 61, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 61}
# {'loss_train': 2.1428861808776856, 'accuracy_train': 0.1856}
# {'loss_test': 2.144174816608429, 'accuracy_test': 0.1841}
# {'bits_sent_up': 19033799744, 'bits_sent_down': 19033799744}
# {'time': 511.2518608570099}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:05:26 [61.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 62, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 62}
# {'loss_train': 2.1372232270240783, 'accuracy_train': 0.1924}
# {'loss_test': 2.141627382040024, 'accuracy_test': 0.1869}
# {'bits_sent_up': 19345829248, 'bits_sent_down': 19345829248}
# {'time': 519.6483359336853}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:05:18 [62.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 63, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 63}
# {'loss_train': 2.1864071464538575, 'accuracy_train': 0.188}
# {'loss_test': 2.1962711095809935, 'accuracy_test': 0.1769}
# {'bits_sent_up': 19657858752, 'bits_sent_down': 19657858752}
# {'time': 527.8691856861115}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:05:10 [63.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 64, 'lr': 0.0480298005, 'epoch': 4, 'iteration': 64}
# {'loss_train': 2.1294485473632814, 'accuracy_train': 0.1874}
# {'loss_test': 2.1273728120326996, 'accuracy_test': 0.1828}
# {'bits_sent_up': 19969888256, 'bits_sent_down': 19969888256}
# {'time': 536.0763535499573}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:05:01 [64.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 65, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 65}
# {'loss_train': 2.139189615249634, 'accuracy_train': 0.1788}
# {'loss_test': 2.133825658559799, 'accuracy_test': 0.179}
# {'bits_sent_up': 20281917760, 'bits_sent_down': 20281917760}
# {'time': 544.2627556324005}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:04:53 [65.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 66, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 66}
# {'loss_train': 2.143378286361694, 'accuracy_train': 0.195}
# {'loss_test': 2.1456468904018404, 'accuracy_test': 0.1857}
# {'bits_sent_up': 20593947264, 'bits_sent_down': 20593947264}
# {'time': 553.197683095932}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:04:44 [66.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 67, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 67}
# {'loss_train': 2.1097434735298157, 'accuracy_train': 0.1948}
# {'loss_test': 2.110225864648819, 'accuracy_test': 0.1878}
# {'bits_sent_up': 20905976768, 'bits_sent_down': 20905976768}
# {'time': 561.7577619552612}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:04:36 [67.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 68, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 68}
# {'loss_train': 2.106716027259827, 'accuracy_train': 0.1882}
# {'loss_test': 2.1064200162887574, 'accuracy_test': 0.1878}
# {'bits_sent_up': 21218006272, 'bits_sent_down': 21218006272}
# {'time': 570.9400389194489}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:04:28 [68.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 69, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 69}
# {'loss_train': 2.1075100898742676, 'accuracy_train': 0.1938}
# {'loss_test': 2.110476620197296, 'accuracy_test': 0.1864}
# {'bits_sent_up': 21530035776, 'bits_sent_down': 21530035776}
# {'time': 579.2086715698242}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:04:20 [69.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 70, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 70}
# {'loss_train': 2.169633424282074, 'accuracy_train': 0.1906}
# {'loss_test': 2.173066248893738, 'accuracy_test': 0.1791}
# {'bits_sent_up': 21842065280, 'bits_sent_down': 21842065280}
# {'time': 587.366979598999}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:04:11 [70.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 71, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 71}
# {'loss_train': 2.178664083480835, 'accuracy_train': 0.1536}
# {'loss_test': 2.1721902537345885, 'accuracy_test': 0.1553}
# {'bits_sent_up': 22154094784, 'bits_sent_down': 22154094784}
# {'time': 595.3813054561615}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:04:03 [71.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 72, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 72}
# {'loss_train': 2.176736421585083, 'accuracy_train': 0.1458}
# {'loss_test': 2.1697607398033143, 'accuracy_test': 0.1506}
# {'bits_sent_up': 22466124288, 'bits_sent_down': 22466124288}
# {'time': 603.8827338218689}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:03:54 [72.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 73, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 73}
# {'loss_train': 2.102117381095886, 'accuracy_train': 0.1672}
# {'loss_test': 2.098440532684326, 'accuracy_test': 0.1675}
# {'bits_sent_up': 22778153792, 'bits_sent_down': 22778153792}
# {'time': 612.6310164928436}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:03:46 [73.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 74, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 74}
# {'loss_train': 2.223701696395874, 'accuracy_train': 0.169}
# {'loss_test': 2.2299630081653596, 'accuracy_test': 0.1616}
# {'bits_sent_up': 23090183296, 'bits_sent_down': 23090183296}
# {'time': 621.0718941688538}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:03:38 [74.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 75, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 75}
# {'loss_train': 2.1171381664276123, 'accuracy_train': 0.1962}
# {'loss_test': 2.1204164314270018, 'accuracy_test': 0.1887}
# {'bits_sent_up': 23402212800, 'bits_sent_down': 23402212800}
# {'time': 629.4056041240692}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:03:29 [75.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 76, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 76}
# {'loss_train': 2.1709076881408693, 'accuracy_train': 0.1824}
# {'loss_test': 2.174125485420227, 'accuracy_test': 0.1751}
# {'bits_sent_up': 23714242304, 'bits_sent_down': 23714242304}
# {'time': 637.7683568000793}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:03:21 [76.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 77, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 77}
# {'loss_train': 2.140629377365112, 'accuracy_train': 0.1968}
# {'loss_test': 2.1467250895500185, 'accuracy_test': 0.1968}
# {'bits_sent_up': 24026271808, 'bits_sent_down': 24026271808}
# {'time': 646.0572233200073}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:03:12 [77.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 78, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 78}
# {'loss_train': 2.141915283203125, 'accuracy_train': 0.1946}
# {'loss_test': 2.1587059938907625, 'accuracy_test': 0.1859}
# {'bits_sent_up': 24338301312, 'bits_sent_down': 24338301312}
# {'time': 654.6896345615387}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:03:04 [78.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 79, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 79}
# {'loss_train': 2.1371556878089906, 'accuracy_train': 0.1776}
# {'loss_test': 2.1540455543994903, 'accuracy_test': 0.1693}
# {'bits_sent_up': 24650330816, 'bits_sent_down': 24650330816}
# {'time': 663.4035680294037}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:02:56 [79.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 80, 'lr': 0.047549502495, 'epoch': 5, 'iteration': 80}
# {'loss_train': 2.0918022203445434, 'accuracy_train': 0.193}
# {'loss_test': 2.0969525289535524, 'accuracy_test': 0.1881}
# {'bits_sent_up': 24962360320, 'bits_sent_down': 24962360320}
# {'time': 671.8347787857056}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:02:47 [80.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 81, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 81}
# {'loss_train': 2.0958240246772766, 'accuracy_train': 0.196}
# {'loss_test': 2.094657326936722, 'accuracy_test': 0.1895}
# {'bits_sent_up': 25274389824, 'bits_sent_down': 25274389824}
# {'time': 680.1195566654205}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:02:39 [81.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 82, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 82}
# {'loss_train': 2.122800326347351, 'accuracy_train': 0.1812}
# {'loss_test': 2.1175880241394043, 'accuracy_test': 0.177}
# {'bits_sent_up': 25586419328, 'bits_sent_down': 25586419328}
# {'time': 688.3653197288513}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:02:31 [82.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 83, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 83}
# {'loss_train': 2.1710842084884643, 'accuracy_train': 0.1698}
# {'loss_test': 2.1645810532569887, 'accuracy_test': 0.1639}
# {'bits_sent_up': 25898448832, 'bits_sent_down': 25898448832}
# {'time': 697.2752714157104}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:02:22 [83.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 84, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 84}
# {'loss_train': 2.091080520153046, 'accuracy_train': 0.1988}
# {'loss_test': 2.0886050450801847, 'accuracy_test': 0.1908}
# {'bits_sent_up': 26210478336, 'bits_sent_down': 26210478336}
# {'time': 705.9153006076813}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:02:14 [84.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 85, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 85}
# {'loss_train': 2.0589818024635314, 'accuracy_train': 0.1942}
# {'loss_test': 2.060508326292038, 'accuracy_test': 0.1914}
# {'bits_sent_up': 26522507840, 'bits_sent_down': 26522507840}
# {'time': 714.3472273349762}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:02:06 [85.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 86, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 86}
# {'loss_train': 2.062574324607849, 'accuracy_train': 0.189}
# {'loss_test': 2.0665986835956573, 'accuracy_test': 0.1873}
# {'bits_sent_up': 26834537344, 'bits_sent_down': 26834537344}
# {'time': 722.5807867050171}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:01:57 [86.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 87, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 87}
# {'loss_train': 2.066776068210602, 'accuracy_train': 0.1864}
# {'loss_test': 2.0724002861976625, 'accuracy_test': 0.1854}
# {'bits_sent_up': 27146566848, 'bits_sent_down': 27146566848}
# {'time': 730.8945260047913}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:01:49 [87.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 88, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 88}
# {'loss_train': 2.065048706531525, 'accuracy_train': 0.191}
# {'loss_test': 2.0707010197639466, 'accuracy_test': 0.1882}
# {'bits_sent_up': 27458596352, 'bits_sent_down': 27458596352}
# {'time': 738.9414160251617}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:01:40 [88.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 89, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 89}
# {'loss_train': 2.0658549809455873, 'accuracy_train': 0.1934}
# {'loss_test': 2.0697022330760957, 'accuracy_test': 0.1913}
# {'bits_sent_up': 27770625856, 'bits_sent_down': 27770625856}
# {'time': 746.869656085968}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:01:32 [89.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 90, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 90}
# {'loss_train': 2.0745567440986634, 'accuracy_train': 0.2002}
# {'loss_test': 2.0777921330928804, 'accuracy_test': 0.1958}
# {'bits_sent_up': 28082655360, 'bits_sent_down': 28082655360}
# {'time': 755.3884181976318}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:01:23 [90.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 91, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 91}
# {'loss_train': 2.101252026557922, 'accuracy_train': 0.2076}
# {'loss_test': 2.1016419422626496, 'accuracy_test': 0.1985}
# {'bits_sent_up': 28394684864, 'bits_sent_down': 28394684864}
# {'time': 764.0401887893677}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:01:15 [91.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 92, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 92}
# {'loss_train': 2.091436107158661, 'accuracy_train': 0.2072}
# {'loss_test': 2.0882992088794707, 'accuracy_test': 0.2007}
# {'bits_sent_up': 28706714368, 'bits_sent_down': 28706714368}
# {'time': 772.4607992172241}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:01:07 [92.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 93, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 93}
# {'loss_train': 2.0487190556526182, 'accuracy_train': 0.2114}
# {'loss_test': 2.0448724222183228, 'accuracy_test': 0.2052}
# {'bits_sent_up': 29018743872, 'bits_sent_down': 29018743872}
# {'time': 780.793464422226}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:58 [93.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 94, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 94}
# {'loss_train': 2.028870279788971, 'accuracy_train': 0.211}
# {'loss_test': 2.0270996785163877, 'accuracy_test': 0.2033}
# {'bits_sent_up': 29330773376, 'bits_sent_down': 29330773376}
# {'time': 788.9474070072174}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:50 [94.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 95, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 95}
# {'loss_train': 2.0439719915390016, 'accuracy_train': 0.197}
# {'loss_test': 2.042656908035278, 'accuracy_test': 0.1938}
# {'bits_sent_up': 29642802880, 'bits_sent_down': 29642802880}
# {'time': 797.0068004131317}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:41 [95.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 96, 'lr': 0.04707400747005, 'epoch': 6, 'iteration': 96}
# {'loss_train': 2.015417630672455, 'accuracy_train': 0.217}
# {'loss_test': 2.0146660304069517, 'accuracy_test': 0.2083}
# {'bits_sent_up': 29954832384, 'bits_sent_down': 29954832384}
# {'time': 805.5963444709778}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:33 [96.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 97, 'lr': 0.0466032673953495, 'epoch': 7, 'iteration': 97}
# {'loss_train': 2.016486666202545, 'accuracy_train': 0.208}
# {'loss_test': 2.0160947024822233, 'accuracy_test': 0.2047}
# {'bits_sent_up': 30266861888, 'bits_sent_down': 30266861888}
# {'time': 814.0112977027893}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:25 [97.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 98, 'lr': 0.0466032673953495, 'epoch': 7, 'iteration': 98}
# {'loss_train': 1.9985356259346008, 'accuracy_train': 0.2204}
# {'loss_test': 1.9965824007987976, 'accuracy_test': 0.2144}
# {'bits_sent_up': 30578891392, 'bits_sent_down': 30578891392}
# {'time': 822.3017621040344}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:16 [98.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 99, 'lr': 0.0466032673953495, 'epoch': 7, 'iteration': 99}
# {'loss_train': 2.029322769641876, 'accuracy_train': 0.2084}
# {'loss_test': 2.0229366528987884, 'accuracy_test': 0.2071}
# {'bits_sent_up': 30890920896, 'bits_sent_down': 30890920896}
# {'time': 830.3998956680298}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:08 [99.00%]
#
# Experiment: main (1/1)
# Evaluate...
# Evaluated on 5000 samples (50 batches)
# Evaluated on 10000 samples (100 batches)
# {'communication_round': 100, 'lr': 0.0466032673953495, 'epoch': 7, 'iteration': 100}
# {'loss_train': 2.026681797504425, 'accuracy_train': 0.2144}
# {'loss_test': 2.025327067375183, 'accuracy_test': 0.2106}
# {'bits_sent_up': 31202950400, 'bits_sent_down': 31202950400}
# {'time': 838.4226069450378}
# Saved results to  results/VGG19/xp_11504.npz
# Remaining Time (approx.): 00:00:00 [100.00%]
